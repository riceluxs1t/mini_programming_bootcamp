# %% [markdown]
# # Homework2
#
# Homework1 은 다들 재미있게 하셨나요?
# (..) 재밌게 하신분들도 있으리라 믿습니다. Homework1 과 마찬가지로 Homework2 도 기본적인 파이썬 문법에 익숙해 지는걸 도와주는 문제들로 구성했습니다.
# 같이 할 수 있는 더 재미난 것들이 산더미인데, 머리속에 있는 걸 파이썬 문법으로 술술 적어내지 못하는건 매우 슬플 것 같아요.
#
#
# # Instructions
#
# 이전 숙제와 마찬가지로 꼭 "homework2.py" 라는 파일명에 작업을 하신 후 숙제를 제출해 주세요.
# 파일 이름이 homework2, 확장자명이 py 입니다. (마치 exe 파일 처럼). 이렇게 제출하지 않으면, 제가 일일이 파일명을 손바줘야 하는 번거로움이 있어요.
#
# 마찬가지로, 구현해야 할 함수 또한 이름을 수정하지 않습니다.
# 더불어, 인풋과 아웃풋 형식또한 수정하지 않습니다.
#
# 그렇지 않으면, 수동으로 코드를 수정해줘야 하는 번거로움이 있어요.

# %%
"""
0번) 문자열 치환.

2020년 드디어 라이스 한인 컴싸 학부생들이 한국형 알파고, J파고의 개발에 성공했습니다.
J파고는 운전에 특히 능한 인공지능 로봇트이며 특히나 Environemnt and Civil engineering 과 관련 된 일에 능한것으로 익히 알려져 있습니다.

하지만, 너무 엔지니어링 기능에 특화 된 나머지 Natural language processing, 특히 Speech 와 관련 된 영역에서는 항상 비슷한 말과

때때로 과묵한 J파고가 탄생해 버렸습니다.

프로그래밍 영재로 알려진 당신은 J파고가 더 사람 다울 수 있도록, 간단한 파이썬 프로그래밍을 도와 J파고 Speech 기능을 고도화 하고자 합니다.

특히, 

("yes", "ok yo")
("no", "lol hell no")
("thanks", "sure thing hommie")

와 같이 (word, sentence) pair 들이 주어질 때, 

당신은 해당 word 를 sentence 로 치환하여 J파고가 좀 더 생동감 있게 말하도록 하고싶습니다.

예를들어,

"yes, thanks" 와 같은 문장을 "ok yo, sure thing hommie" 와 같이 변형해서 말하도록 하고 싶습니다.

J파고의 원래 문장과 (python string type), (word, sentence) pair 들이 list 안에 담겨 주어질 때,

J파고를 도와 해당 문장을 사람다운 언어로 바꿔주세요

================================================
힌트 a = ("yes", "ok yo") 와 같은 문법은 파이썬에서도 적법한 문법입니다. list 와 마찬가지로 첫번째 아이템은 a[0] (== "yes"), 두번째는 a[1] (== "ok yo") 와 같이
접근 할 수 있습니다.

"""


def help_jpago(original_sentence, list_of_pairs):
    pass

# %%
"""

1번) Anagram.

ABCD 와 CBAD 는 서로 anagram 관계에 있다고 합니다.
어떤 문자열 s에 대하여, s의 anagram 이란 one or more characters 의 순서를 섞어놓은 문자열을 말합니다.

두 문자열, s1, s2 가 주어질 때, 서로가 서로의 anagram 인지 판별하여 주세요.

anagram 관계에 있으면 True 를 그렇지 않으면 False 를 리턴해 주세요.

i.e.

print is_anagram("heyo", "ehyo") # True
print is_anagram("heyo", "yolo") # False

"""

def is_anagram(s1, s2):
    pass

# %%
"""

2번) Almost anagram.

ABCD 와 CBAD 는 다음과 같을 때, "almost anagram" 관계에 있다고 합니다.

1) one word is shorter than the other by one letter but otherwise contains the same letters in any order
2) the two words are the same length and their character multisets differ by one character only e.g. “aaa” and “aab”

주어진 두 문자열 s1, s2 에 대하여, 다음과 같이 출력해주세요
1) "identical" 출력 if s1 == s2
2) "anagram" 출력 if s1 is an anagram of s2
3) "almost anagram" 출력 if s1 is an almost anagram of s2 (or vice versa)
4) "nothing" if s1 and s2 are in none of the above relationships.

"""

def is_almost_anagram(s1, s2):
    pass

# %%
"""

3번) Poker chip shuffle.

먼저 아래 동영상을 감상해주세요.
https://www.youtube.com/watch?v=kGy0bVADg3E

There are two poker chip stacks of size n of different colors.

You initially begin with two stacks where each stack has n chips in it of the same color.

i.e.

r b
r b
r b 

(stacks of size 4, one which consists of all red chips and the other of all blue chips)

You start shuffling the chips by the trick as done in the youtube vidoe (the left first shuffle)

1) first shuffle
b
r
b
r
b
r

after splitting gives you, two stacks as follows

r b
b r
r b

2) second shuffle

b
r
r
b
b
r

after splitting gives you, two stacks as follows

b b
b r
r r

3) third shuffle

b
b
r
b
r
r

after splitting gives you, two stacks as follows

b b
r b
r r

4) final shuffle

b
b
b
r
r
r

after splitting gives you, two stacks as follows

r b
r b
r b



Your job is to count how many shuffles it takes before you end up with stacks of the unifrom colors. 

There are certain rules of this trick, however.

1) when you shuffle, you shuffle in a consistent manner. For each shuffel, two stacks you start with (denote them l, r)
are interleaved with either l[0] on the bottom or r[0] on the bottom in a consistent manner. l[0], r[0] denote the 
bottom most chip in stacks l and r.

We call the "left first shuffle" as one in which l[0] comes on the bottom consistently. and the "right first shuffle" 
as one in which r[0] comes on the bottom consistently.

2) When you shuffle and have a stack of size 2*n, you always split in such a way that the top 'n' chips make up your 
right stack and the bottom n chips make up your left stack.

for example,

r
r
b
b

after splitting becomes,

b r
b r

not 

r b
r b 



Given a stack size n (so that you have two stacks of size n to begin with) and 
a boolean indicator is_left (whether True or False. True if the left first shuffle, False if the right first shuffle),

Find the minimum # number of shuffles it takes to end up with stcaks of the uniform colors again.

i.e. your function terminates when
you either have

r b
r b
r b

or

b r
b r
b r

"""
def poker_chip_shuffle(stack_size, is_left):
    pass

# %%
"""

you notice that the above poker chip shuffle method gives different optimal answers for different stack sizes.

Particularly, you notice that depending on whether you do the left or right first shuffle, you end up with different
answers for the same stack size.

what if you had the option of choosing either the left or right first shuffle for each shuffle and you would be interested

in finding the shortest number of shuffles in general for a given stack size n.

For example,

In the example given in the last problem description, if the third shuffle had been done instead in the right first shuffle fashion,

that would give you two stacks of the same colors without subsequently performing one more extra shuffle.

Interestingly, this has been the subject of discussion among the Korean Rice Poker Club members who are all excellent

poker players but are too lazy to perform repetitive shuffle tricks to figure this out on their own.

With your programming skill,

Please help the Korean Rice Poker Club find the optimal number of shuffles for a given stack size.

"""

def poker_chip_shuffle_optimal(stack_size):
    pass
